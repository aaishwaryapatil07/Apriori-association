# %% [markdown]
# ## Market Basket Optimization- Apriori Algorithm
#
# * The purpose of market basket analysis is to determine what products customers purchase together. It takes its name from the idea of customers throwing all their purchases into a shopping cart (a "market basket") during grocery shopping.
# * Market-Basket-Analysis Using Apriori Algorithm is to do Market Basket Analysis of Customers purchasing behaviours. It can predict what the customer is going to buy next by looking at the products he is buying and decides the location and promotion  of the items.
#
# **Input File**:
# This File contains information about Customers buying different grocery items at a Mall

# %% [markdown]
# #### Import Pandas library

# %%
import pandas as pd

# %%
df = pd.read_csv('Market_Basket_Optimisation.csv',header=None)

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 20 columns):
# 0     7501 non-null object
# 1     5747 non-null object
# 2     4389 non-null object
# 3     3345 non-null object
# 4     2529 non-null object
# 5     1864 non-null object
# 6     1369 non-null object
# 7     981 non-null object
# 8     654 non-null object
# 9     395 non-null object
# 10    256 non-null object
# 11    154 non-null object
# 12    87 non-null object
# 13    47 non-null object
# 14    25 non-null object
# 15    8 non-null object
# 16    4 non-null object
# 17    4 non-null object
# 18    3 non-null object
# 19    1 non-null object
# dtypes: object(20)
# memory usage: 1.1+ MB

# %% [markdown]
# ### There are 3 factors which determines the associvity of things: Lift, Confidence and Support

# %% [markdown]
# * **Support:** Support is the number of transactions that include items in the {A} and {B} parts of the rule as a percentage of the total number of transactions. It is a measure of how frequently the collection of items occur together as a percentage of all transactions.<br>
#     **Formula:** (A+B)/Total <br>
# * **Confidence:** Confidence of the rule is the ratio of the number of transactions that include all items in {B} as well as the number of transactions that include all items in {A} to the number of transactions that include all items in {A}<br>
#     **Formula:** (A+B)/A <br>
# * **lift:** Lift is the ratio of confidence to expected confidence. Expected confidence is the confidence divided by the frequency of B. The Lift tells us how much better a rule is at predicting the result than just assuming the result in the first place. Greater lift values indicate stronger associations<br>
#     **Formula:** ((A+B)/A)/(B/total)) <br>

# %%
df.values
# Out:
# array([['shrimp', 'almonds', 'avocado', ..., 'frozen smoothie',
#         'spinach', 'olive oil'],
#        ['burgers', 'meatballs', 'eggs', ..., nan, nan, nan],
#        ['chutney', nan, nan, ..., nan, nan, nan],
#        ...,
#        ['chicken', nan, nan, ..., nan, nan, nan],
#        ['escalope', 'green tea', nan, ..., nan, nan, nan],
#        ['eggs', 'frozen smoothie', 'yogurt cake', ..., nan, nan, nan]],
#       dtype=object)

# %%
data = []
for i in range(0,7501):
    data.append([df.values[i,j] for j in range(0,20) if str(df.values[i,j]) != 'nan'])

# %%
data
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
data = []
for i in range(0,7501):
    data.append([df.iloc[i,j] for j in range(0,20) if str(df.values[i,j]) != 'nan' ])

# %%
data
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
from apyori import apriori

# %%
## min_support = purchaesd 3 times a day(7*3 = 21), 21/7500
## min_lenght = bills should atleast contain 2 items
## min_confidence, min_lift is assumed
rules = apriori(data, min_support = 0.003, min_confidence=0.2, min_lift=3, min_length= 2)

# %%
result = list(rules)

# %%
len(result)
# Out:
# 77

# %%
result
# Out:
# [RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %%
result[0]
# Out:
# RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)])

# %%
# realtion between below element
result[0].items
# Out:
# frozenset({'chicken', 'light cream'})

# %%
result[0].support
# Out:
# 0.004532728969470737

# %%
result[0].ordered_statistics
# Out:
# [OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]

# %%
result[0].ordered_statistics[0]
# Out:
# OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)

# %%
# base item is the item with its respect the other item is considered
result[0].ordered_statistics[0].items_base
# Out:
# frozenset({'light cream'})

# %%
result[0].ordered_statistics[0].items_add
# Out:
# frozenset({'chicken'})

# %%
result[0].ordered_statistics[0].confidence
# Out:
# 0.29059829059829057

# %%
result[0].ordered_statistics[0].lift
# Out:
# 4.84395061728395

# %%
for i in range(0,78):
    print(result[i].ordered_statistics[0].items_base)
    print(result[i].ordered_statistics[0].items_add)
    print(result[i].ordered_statistics[0].confidence)
    print('*************')
# Out:
# frozenset({'light cream'})
# frozenset({'chicken'})
# 0.29059829059829057
# *************
# frozenset({'mushroom cream sauce'})
# frozenset({'escalope'})
# 0.3006993006993007
# *************
# frozenset({'pasta'})
# frozenset({'escalope'})
# 0.3728813559322034
# *************
# frozenset({'fromage blanc'})
# frozenset({'honey'})
# 0.2450980392156863
# *************
# frozenset({'herb & pepper'})
# frozenset({'ground beef'})
# 0.3234501347708895
# *************
# frozenset({'tomato sauce'})
# frozenset({'ground beef'})
# 0.3773584905660377
# *************
# frozenset({'light cream'})
# frozenset({'olive oil'})
# 0.20512820512820515
# *************
# frozenset({'whole wheat pasta'})
# frozenset({'olive oil'})
# 0.2714932126696833
# *************
# frozenset({'pasta'})
# frozenset({'shrimp'})
# 0.3220338983050847
# *************
# frozenset({'avocado', 'spaghetti'})
# frozenset({'milk'})
# 0.41666666666666663
# *************
# frozenset({'milk', 'cake'})
# frozenset({'burgers'})
# ...

# %%
df = pd.DataFrame(columns= ['items_base','items_add','confidence'])

for i in range(0,77):
    ib=result[i].ordered_statistics[0].items_base
    ia=result[i].ordered_statistics[0].items_add
    c=result[i].ordered_statistics[0].confidence
    df.loc[i] = [ib,ia,c]

# %%
df
# Out:
#                                          items_base            items_add  \
# 0                                     (light cream)            (chicken)
# 1                            (mushroom cream sauce)           (escalope)
# 2                                           (pasta)           (escalope)
# 3                                   (fromage blanc)              (honey)
# 4                                   (herb & pepper)        (ground beef)
# 5                                    (tomato sauce)        (ground beef)
# 6                                     (light cream)          (olive oil)
# 7                               (whole wheat pasta)          (olive oil)
# 8                                           (pasta)             (shrimp)
# 9                              (avocado, spaghetti)               (milk)
# 10                                     (milk, cake)            (burgers)
# 11                              (chocolate, turkey)            (burgers)
# ...

# %%
df[df['confidence']==0.6764705882352942]
# Out:
#                 items_base    items_add  confidence
# 14  (cereals, ground beef)  (spaghetti)    0.676471

# %%
df[df['confidence']== df['confidence'].max()]
# Out:
#                 items_base    items_add  confidence
# 14  (cereals, ground beef)  (spaghetti)    0.676471
